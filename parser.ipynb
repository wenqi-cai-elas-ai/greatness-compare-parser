# %%
import pandas as pd
import os
import numpy as np

# %%
text = """
ML Engine metrics
ALL Dataset
Project name      	      Greatness      	Dataset length
Lodur_Talos2_AMD_2Hz_Leave2...master	90.653247977%	 42 hours, 39 minutes ( 100% )
Lodur_Talos2_AMD_2Hz_Leave2...v1	97.981866138%	 42 hours, 39 minutes ( 100% )
TEST Dataset
Project name      	      Greatness      	Dataset length
Lodur_Talos2_AMD_2Hz_Leave2...master	92.813525995%	  8 hours, 28 minutes ( 20% )
Lodur_Talos2_AMD_2Hz_Leave2...v1	97.489230152%	  8 hours, 28 minutes ( 20% )
TRAIN Dataset
Project name      	      Greatness      	Dataset length
Lodur_Talos2_AMD_2Hz_Leave2...master	90.097105031%	 20 hours, 56 minutes ( 49% )
Lodur_Talos2_AMD_2Hz_Leave2...v1	98.287525778%	 20 hours, 56 minutes ( 49% )
VALIDATE Dataset
Project name      	      Greatness      	Dataset length
Lodur_Talos2_AMD_2Hz_Leave2...master	89.968984814%	 13 hours, 14 minutes ( 31% )
Lodur_Talos2_AMD_2Hz_Leave2...v1	97.867842099%	 13 hours, 14 minutes ( 31% )
ML Engine metrics
ALL Dataset
Project name      	      Greatness      	Dataset length
Lodur_Jingwei14_Intel_2Hz...master	96.357216278%	 41 hours, 45 minutes ( 100% )
Lodur_Jingwei14_Intel_2Hz...v1	87.806642516%	 41 hours, 45 minutes ( 100% )
TEST Dataset
Project name      	      Greatness      	Dataset length
Lodur_Jingwei14_Intel_2Hz...master	94.565801600%	  8 hours, 10 minutes ( 20% )
Lodur_Jingwei14_Intel_2Hz...v1	85.386800063%	  8 hours, 10 minutes ( 20% )
TRAIN Dataset
Project name      	      Greatness      	Dataset length
Lodur_Jingwei14_Intel_2Hz...master	97.020710939%	 20 hours, 42 minutes ( 50% )
Lodur_Jingwei14_Intel_2Hz...v1	87.994457598%	 20 hours, 42 minutes ( 50% )
VALIDATE Dataset
Project name      	      Greatness      	Dataset length
Lodur_Jingwei14_Intel_2Hz...master	96.507320008%	 12 hours, 52 minutes ( 31% )
Lodur_Jingwei14_Intel_2Hz...v1	89.114920451%	 12 hours, 52 minutes ( 31% )
ML Engine metrics
ALL Dataset
Project name      	      Greatness      	Dataset length
Lodur_Griffin2_Intel_2Hz...master	98.382106348%	 86 hours, 56 minutes ( 100% )
Lodur_Griffin2_Intel_2Hz...v1	95.357761408%	 86 hours, 56 minutes ( 100% )
TEST Dataset
Project name      	      Greatness      	Dataset length
Lodur_Griffin2_Intel_2Hz...master	98.317706139%	 18 hours, 13 minutes ( 21% )
Lodur_Griffin2_Intel_2Hz...v1	94.944459007%	 18 hours, 13 minutes ( 21% )
TRAIN Dataset
Project name      	      Greatness      	Dataset length
Lodur_Griffin2_Intel_2Hz...master	98.661203521%	 44 hours, 21 minutes ( 51% )
Lodur_Griffin2_Intel_2Hz...v1	95.757179795%	 44 hours, 21 minutes ( 51% )
VALIDATE Dataset
Project name      	      Greatness      	Dataset length
Lodur_Griffin2_Intel_2Hz...master	97.866398636%	 24 hours, 21 minutes ( 28% )
Lodur_Griffin2_Intel_2Hz...v1	94.889566326%	 24 hours, 21 minutes ( 28% )
ML Engine metrics
ALL Dataset
Project name      	      Greatness      	Dataset length
Lodur_Libra2_Intel_2Hz...master	99.848223333%	 82 hours, 31 minutes ( 100% )
Lodur_Libra2_Intel_2Hz...v1	96.402165458%	 82 hours, 31 minutes ( 100% )
TEST Dataset
Project name      	      Greatness      	Dataset length
Lodur_Libra2_Intel_2Hz...master	99.878074305%	 14 hours, 36 minutes ( 18% )
Lodur_Libra2_Intel_2Hz...v1	97.945105857%	 14 hours, 36 minutes ( 18% )
TRAIN Dataset
Project name      	      Greatness      	Dataset length
Lodur_Libra2_Intel_2Hz...master	99.810939571%	 45 hours, 07 minutes ( 55% )
Lodur_Libra2_Intel_2Hz...v1	97.697309864%	 45 hours, 07 minutes ( 55% )
VALIDATE Dataset
Project name      	      Greatness      	Dataset length
Lodur_Libra2_Intel_2Hz...master	99.893754111%	 22 hours, 48 minutes ( 28% )
Lodur_Libra2_Intel_2Hz...v1	93.199204166%	 22 hours, 48 minutes ( 28% )
ML Engine metrics
ALL Dataset
Project name      	      Greatness      	Dataset length
Lodur_Fenrir2_Yoga_Intel_2Hz_Leave2...master	91.706405361%	 27 hours, 42 minutes ( 100% )
Lodur_Fenrir2_Yoga_Intel_2Hz_Leave2...v1	94.641428307%	 27 hours, 42 minutes ( 100% )
TEST Dataset
Project name      	      Greatness      	Dataset length
Lodur_Fenrir2_Yoga_Intel_2Hz_Leave2...master	98.756653297%	  4 hours, 39 minutes ( 17% )
Lodur_Fenrir2_Yoga_Intel_2Hz_Leave2...v1	97.713075651%	  4 hours, 39 minutes ( 17% )
TRAIN Dataset
Project name      	      Greatness      	Dataset length
Lodur_Fenrir2_Yoga_Intel_2Hz_Leave2...master	88.699765941%	 16 hours, 26 minutes ( 59% )
Lodur_Fenrir2_Yoga_Intel_2Hz_Leave2...v1	94.263372874%	 16 hours, 26 minutes ( 59% )
VALIDATE Dataset
Project name      	      Greatness      	Dataset length
Lodur_Fenrir2_Yoga_Intel_2Hz_Leave2...master	98.636673307%	  6 hours, 36 minutes ( 24% )
Lodur_Fenrir2_Yoga_Intel_2Hz_Leave2...v1	93.505437609%	  6 hours, 36 minutes ( 24% )
ML Engine metrics
ALL Dataset
Project name      	      Greatness      	Dataset length
Lodur_Cheetah3_Intel_2Hz...master	93.095953498%	128 hours, 52 minutes ( 100% )
Lodur_Cheetah3_Intel_2Hz...v1	87.923871783%	128 hours, 54 minutes ( 100% )
TEST Dataset
Project name      	      Greatness      	Dataset length
Lodur_Cheetah3_Intel_2Hz...master	93.027772536%	 22 hours, 26 minutes ( 17% )
Lodur_Cheetah3_Intel_2Hz...v1	87.013025154%	 22 hours, 27 minutes ( 17% )
TRAIN Dataset
Project name      	      Greatness      	Dataset length
Lodur_Cheetah3_Intel_2Hz...master	94.202883259%	 71 hours, 30 minutes ( 55% )
Lodur_Cheetah3_Intel_2Hz...v1	90.271446163%	 71 hours, 31 minutes ( 55% )
VALIDATE Dataset
Project name      	      Greatness      	Dataset length
Lodur_Cheetah3_Intel_2Hz...master	90.466372350%	 34 hours, 55 minutes ( 27% )
Lodur_Cheetah3_Intel_2Hz...v1	82.869072966%	 34 hours, 55 minutes ( 27% )
ML Engine metrics
ALL Dataset
Project name      	      Greatness      	Dataset length
Lodur_Fenrir2_Yoga_AMD_2Hz_Leave2...master	62.717745625%	148 hours, 34 minutes ( 100% )
Lodur_Fenrir2_Yoga_AMD_2Hz_Leave2...v1	93
)
VALIDATE Dataset
Project name      	      Greatness      	Dataset length
Lodur_Missouri_Intel_2Hz...master	98.272037795%	 23 hours, 40 minutes ( 27% )
Lodur_Missouri_Intel_2Hz...v1	92.950991124%	 23 hours, 40 minutes ( 27% )
ML Engine metrics
ALL Dataset
Project name      	      Greatness      	Dataset length
Lodur_Griffin2_AMD_2Hz...master	99.654804977%	 28 hours, 12 minutes ( 100% )
Lodur_Griffin2_AMD_2Hz...v1	98.673554462%	 28 hours, 12 minutes ( 100% )
TEST Dataset
Project name      	      Greatness      	Dataset length
Lodur_Griffin2_AMD_2Hz...master	99.434551622%	  4 hours, 40 minutes ( 17% )
Lodur_Griffin2_AMD_2Hz...v1	99.150093764%	  4 hours, 40 minutes ( 17% )
TRAIN Dataset
Project name      	      Greatness      	Dataset length
Lodur_Griffin2_AMD_2Hz...master	99.852396980%	 14 hours, 26 minutes ( 51% )
Lodur_Griffin2_AMD_2Hz...v1	99.286580562%	 14 hours, 26 minutes ( 51% )
VALIDATE Dataset
Project name      	      Greatness      	Dataset length
Lodur_Griffin2_AMD_2Hz...master	99.444547761%	  9 hours, 05 minutes ( 32% )
Lodur_Griffin2_AMD_2Hz...v1	97.318513156%	  9 hours, 05 minutes ( 32% )
ML Engine metrics
ALL Dataset
Project name      	      Greatness      	Dataset length
Lodur_Fenrir2_Intel_2Hz...master	95.885696181%	121 hours, 26 minutes ( 100% )
Lodur_Fenrir2_Intel_2Hz...v1	87.657272998%	121 hours, 26 minutes ( 100% )
TEST Dataset
Project name      	      Greatness      	Dataset length
Lodur_Fenrir2_Intel_2Hz...master	94.118833721%	 23 hours, 32 minutes ( 19% )
Lodur_Fenrir2_Intel_2Hz...v1	86.297660812%	 23 hours, 32 minutes ( 19% )
TRAIN Dataset
Project name      	      Greatness      	Dataset length
Lodur_Fenrir2_Intel_2Hz...master	97.142315820%	 61 hours, 30 minutes ( 51% )
Lodur_Fenrir2_Intel_2Hz...v1	90.573366581%	 61 hours, 30 minutes ( 51% )
VALIDATE Dataset
Project name      	      Greatness      	Dataset length
Lodur_Fenrir2_Intel_2Hz...master	94.880856119%	 36 hours, 23 minutes ( 30% )
Lodur_Fenrir2_Intel_2Hz...v1	83.479457947%	 36 hours, 23 minutes ( 30% )
ML Engine metrics
ALL Dataset
Project name      	      Greatness      	Dataset length
Lodur_Golem2_Intel_2Hz...master	96.802199383%	 98 hours, 15 minutes ( 100% )
Lodur_Golem2_Intel_2Hz...v1	93.565162081%	 98 hours, 15 minutes ( 100% )
TEST Dataset
Project name      	      Greatness      	Dataset length
Lodur_Golem2_Intel_2Hz...master	94.706637340%	 19 hours, 42 minutes ( 20% )
Lodur_Golem2_Intel_2Hz...v1	90.029718781%	 19 hours, 42 minutes ( 20% )
TRAIN Dataset
Project name      	      Greatness      	Dataset length
Lodur_Golem2_Intel_2Hz...master	98.000271238%	 48 hours, 46 minutes ( 50% )
Lodur_Golem2_Intel_2Hz...v1	95.915985959%	 48 hours, 46 minutes ( 50% )
VALIDATE Dataset
Project name      	      Greatness      	Dataset length
Lodur_Golem2_Intel_2Hz...master	96.194877187%	 29 hours, 47 minutes ( 30% )
Lodur_Golem2_Intel_2Hz...v1	92.151476614%	 29 hours, 47 minutes ( 30% )
ML Engine metrics
ALL Dataset
Project name      	      Greatness      	Dataset length
Lodur_Phoenix2_Intel_2Hz_Leave2...master	99.148678674%	 96 hours, 52 minutes ( 100% )
Lodur_Phoenix2_Intel_2Hz_Leave2...v1	97.006557556%	 96 hours, 52 minutes ( 100% )
TEST Dataset
Project name      	      Greatness      	Dataset length
Lodur_Phoenix2_Intel_2Hz_Leave2...master	97.996979601%	 19 hours, 17 minutes ( 20% )
Lodur_Phoenix2_Intel_2Hz_Leave2...v1	95.534083267%	 19 hours, 17 minutes ( 20% )
TRAIN Dataset
Project name      	      Greatness      	Dataset length
Lodur_Phoenix2_Intel_2Hz_Leave2...master	99.583077170%	 49 hours, 16 minutes ( 51% )
Lodur_Phoenix2_Intel_2Hz_Leave2...v1	98.369332917%	 49 hours, 16 minutes ( 51% )
VALIDATE Dataset
Project name      	      Greatness      	Dataset length
Lodur_Phoenix2_Intel_2Hz_Leave2...master	99.127700790%	 28 hours, 17 minutes ( 29% )
Lodur_Phoenix2_Intel_2Hz_Leave2...v1	95.497863917%	 28 hours, 17 minutes ( 29% )
ML Engine metrics
ALL Dataset
Project name      	      Greatness      	Dataset length
Lodur_Rhone_Intel_2Hz...master	95.632330141%	 86 hours, 55 minutes ( 100% )
Lodur_Rhone_Intel_2Hz...v1	91.012698549%	 86 hours, 55 minutes ( 100% )
TEST Dataset
Project name      	      Greatness      	Dataset length
Lodur_Rhone_Intel_2Hz...master	96.851191102%	 14 hours, 38 minutes ( 17% )
Lodur_Rhone_Intel_2Hz...v1	91.526779966%	 14 hours, 38 minutes ( 17% )
TRAIN Dataset
Project name      	      Greatness      	Dataset length
Lodur_Rhone_Intel_2Hz...master	94.331355494%	 48 hours, 55 minutes ( 56% )
Lodur_Rhone_Intel_2Hz...v1	91.077574500%	 48 hours, 55 minutes ( 56% )
VALIDATE Dataset
Project name      	      Greatness      	Dataset length
Lodur_Rhone_Intel_2Hz...master	97.398638391%	 23 hours, 21 minutes ( 27% )
Lodur_Rhone_Intel_2Hz...v1	90.573702005%	 23 hours, 21 minutes ( 27% )
ML Engine metrics
ALL Dataset
Project name      	      Greatness      	Dataset length
Lodur_Cheetah3Touch_Intel_2Hz...master
)
Lodur_Golem2_AMD_2Hz_Leave2...v1	96.335849576%	 23 hours, 25 minutes ( 49% )
VALIDATE Dataset
Project name      	      Greatness      	Dataset length
Lodur_Golem2_AMD_2Hz_Leave2...master	90.493843422%	 14 hours, 36 minutes ( 31% )
Lodur_Golem2_AMD_2Hz_Leave2...v1	96.724864405%	 14 hours, 36 minutes ( 31% )
"""

# %%
def parse_pipeline_results(text):
    results = []
    dataset = None
    for line in text.split("\n"):
        if line.startswith("ML") or line.startswith("Project name"):
            continue
        elif any(list(map(line.startswith, ["ALL", "TEST", "TRAIN", "VALIDATE"]))):
            dataset = line.split()[0].capitalize()
        else:
            splits = line.split("\t")
            if len(splits) > 1:
                project = splits[0].split("...")[0]
                branch = splits[0].split("...")[1]
                greatness = float(splits[1].replace("%", ""))

                if len(results) and results[-1]["project"] == project and results[-1]["dataset"] == dataset:
                    results[-1].update({
                        f"{branch}/greatness": greatness
                    })
                else:
                    results.append({
                        "project": project,
                        "dataset": dataset,
                        # "branch": branch, 
                        f"{branch}/greatness": greatness,
                    })

    return pd.DataFrame(results)

def parse_and_export_excel(text, out_filename):
    # Parse the results as a DataFrame
    df = parse_pipeline_results(text)

    # Filter columns
    branch_metric_name = None
    for col in df.columns:
        if "greatness" in col and not "master" in col:
            branch_metric_name = col
            break

    df = df[["project", "dataset", branch_metric_name, "master/greatness"]]
    
    df = df.sort_values(by=["project", "dataset"])
    df["delta/greatness"] = df["v1/greatness"] - df["master/greatness"]
    df["delta/bool"] = (df["delta/greatness"] > 0)

    df = df.drop_duplicates()

    # Formatting numbers 
    for col in df.columns:
        if "greatness" in col:
            df[col] = df[col].apply(lambda x: f"{np.round(x, 2)} %")

    # Export to excel
    df.to_excel(out_filename, index=False)

# %%
# df = parse_pipeline_results(text)
parse_and_export_excel(
    text, 
    out_filename=os.path.join(os.getcwd(), "all_time_reverse_0.06.xlsx"),
)

# %%
print(os.path.join(os.getcwd(), "all_time_reverse_baseline.xlsx"))
# Out:
# c:\Users\hector.martel\Documents\Tasks\greatness_compare_parser\all_time_reverse.xlsx

# %%
# df.head(len(df))
# Out:
#                          project   dataset  master/greatness  v1/greatness
# 0    Lodur_Talos2_AMD_2Hz_Leave2       All         90.653248     97.981866
# 1    Lodur_Talos2_AMD_2Hz_Leave2      Test         92.813526     97.489230
# 2    Lodur_Talos2_AMD_2Hz_Leave2     Train         90.097105     98.287526
# 3    Lodur_Talos2_AMD_2Hz_Leave2  Validate         89.968985     97.867842
# 4      Lodur_Jingwei14_Intel_2Hz       All         96.357216     87.806643
# ..                           ...       ...               ...           ...
# 119  Lodur_Roc2_Intel_2Hz_Leave2  Validate         99.086361     97.217859
# 120  Lodur_Golem2_AMD_2Hz_Leave2       All         88.823040     96.161376
# 121  Lodur_Golem2_AMD_2Hz_Leave2      Test         87.457008     94.863427
# 122  Lodur_Golem2_AMD_2Hz_Leave2     Train         88.348733     96.335850
# 123  Lodur_Golem2_AMD_2Hz_Leave2  Validate         90.493843     96.724864
#
# [124 rows x 4 columns]
